# %% [markdown]
# <a href="https://colab.research.google.com/github/jjlevine11/ds1002-tut9yt/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt

plt.pie(slices, labels = ["US", "UK", "MX", "CA", "JP"])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n)
# Out:
# (array([  8.,  60., 199., 381., 623., 727., 565., 282., 109.,  46.]),
#  array([426.85017218, 427.44941008, 428.04864799, 428.64788589,
#         429.2471238 , 429.84636171, 430.44559961, 431.04483752,
#         431.64407542, 432.24331333, 432.84255123]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.scatter(x,y)
z = np.polyfit(x, y, 2)
p = np.poly1d(z)
plt.plot(x, p(x))
plt.scatter(x,y)
