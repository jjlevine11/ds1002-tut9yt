# %% [markdown]
# <a href="https://colab.research.google.com/github/jjlevine11/ds1002-tut9yt/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get the head rows - whatever number I want
mock_data.head(30)
# Out:
#     id  first_name    last_name                       email       gender  age
# 0    1      Patric         Foss  pfoss0@cargocollective.com         Male   46
# 1    2       Hetti      Houchin           hhouchin1@sun.com       Female   11
# 2    3    Trumaine    Francesch  tfrancesch2@privacy.gov.au         Male   22
# 3    4      Hallsy     Mandrier       hmandrier3@census.gov         Male   78
# 4    5  Cinderella     Lympenie         clympenie4@imdb.com     Bigender    9
# 5    6        Suki     Schultes     sschultes5@addtoany.com       Female   36
# 6    7    Montague     Antcliff          mantcliff6@ucoz.ru         Male   46
# 7    8      Blanca     Venditti      bvenditti7@twitter.com       Female   83
# 8    9       Keven      Sherrin       ksherrin8@comcast.net         Male   61
# 9   10      Nellie      Skeemer      nskeemer9@berkeley.edu       Female   15
# 10  11       Lukas  Jedraszczyk       ljedraszczyka@sun.com         Male   81
# ...

# %%
mock_data.tail()
# Out:
#        id  first_name last_name                      email  gender  age
# 995   996         See  Godthaab  sgodthaabrn@bloomberg.com    Male   48
# 996   997       Viola     Trail     vtrailro@pinterest.com  Female   67
# 997   998       Barby  Mildmott  bmildmottrp@google.com.hk  Female   51
# 998   999     Trumann   Ruffler    trufflerrq@symantec.com    Male   23
# 999  1000  Petronilla  Greenrde       pgreenrderr@ucla.edu  Female   20

# %%
#grab specific row
mock_data.loc[4]
# Out:
# id                              5
# first_name             Cinderella
# last_name                Lympenie
# email         clympenie4@imdb.com
# gender                   Bigender
# age                             9
# Name: 4, dtype: object

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.166000
# std     288.819436    26.177771
# min       1.000000     1.000000
# 25%     250.750000    22.000000
# 50%     500.500000    46.000000
# 75%     750.250000    68.000000
# max    1000.000000    90.000000

# %%
# get the columns from the df
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# what data types are in this df?
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
# renmae first name and last name
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head
# Out:
# <bound method NDFrame.head of        id       fname      lname                       email    gender  age
# 0       1      Patric       Foss  pfoss0@cargocollective.com      Male   46
# 1       2       Hetti    Houchin           hhouchin1@sun.com    Female   11
# 2       3    Trumaine  Francesch  tfrancesch2@privacy.gov.au      Male   22
# 3       4      Hallsy   Mandrier       hmandrier3@census.gov      Male   78
# 4       5  Cinderella   Lympenie         clympenie4@imdb.com  Bigender    9
# ..    ...         ...        ...                         ...       ...  ...
# 995   996         See   Godthaab   sgodthaabrn@bloomberg.com      Male   48
# 996   997       Viola      Trail      vtrailro@pinterest.com    Female   67
# 997   998       Barby   Mildmott   bmildmottrp@google.com.hk    Female   51
# 998   999     Trumann    Ruffler     trufflerrq@symantec.com      Male   23
# 999  1000  Petronilla   Greenrde        pgreenrderr@ucla.edu    Female   20
#
# [1000 rows x 6 columns]>

# %%
#get specific column
mock_data['fname']
# Out:
# 0          Patric
# 1           Hetti
# 2        Trumaine
# 3          Hallsy
# 4      Cinderella
#           ...
# 995           See
# 996         Viola
# 997         Barby
# 998       Trumann
# 999    Petronilla
# Name: fname, Length: 1000, dtype: object

# %%
# get two columns
mock_data[['fname','lname']]
# Out:
#           fname      lname
# 0        Patric       Foss
# 1         Hetti    Houchin
# 2      Trumaine  Francesch
# 3        Hallsy   Mandrier
# 4    Cinderella   Lympenie
# ..          ...        ...
# 995         See   Godthaab
# 996       Viola      Trail
# 997       Barby   Mildmott
# 998     Trumann    Ruffler
# 999  Petronilla   Greenrde
#
# [1000 rows x 2 columns]

# %%
# plot of specific column
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
# mean age of each gender
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        43.750000
# Bigender       45.625000
# Female         44.671171
# Genderfluid    52.272727
# Genderqueer    46.312500
# Male           45.544218
# Non-binary     35.722222
# Polygender     49.533333
# Name: age, dtype: float64
